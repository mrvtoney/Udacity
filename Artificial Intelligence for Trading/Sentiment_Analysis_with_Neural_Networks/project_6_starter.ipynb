# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement 
len(twits['data'])
# Out:
# 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'https?;\/\/.*[\r\n]*', ' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'[$][A-Za-z][\S]*', ' ', text)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'[@][A-Za-z][\S]*', ' ', text)

    # Replace everything not a letter with a space
    text = re.sub(r'[\W_]+', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split()

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [wnl.lemmatize(token) for token in tokens if len(token) > 1]
    
    return tokens
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement

tokenized = [preprocess(message) for message in messages]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter


"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 

bow_list = Counter([word for token in tokenized for word in token])
bow = dict(bow_list)

bow
# Out:
# {'great': 17761,
#  'buy': 79861,
#  'at': 140756,
#  '26': 17084,
#  '00': 23728,
#  'ill': 891,
#  'wait': 11391,
#  'staanalystalert': 4072,
#  'for': 282631,
#  'jefferies': 1232,
#  'maintains': 965,
#  'with': 71994,
#  'rating': 16785,
#  'of': 218816,
#  'hold': 22839,
#  'setting': 3924,
#  'target': 18477,
#  'price': 40375,
#  'usd': 2953,
#  '350': 2594,
#  'our': 12369,
#  'own': 9144,
#  'verdict': 3747,
#  'is': 289023,
#  'http': 424333,
#  'www': 231690,
#  'stocktargetadvisor': 3656,
#  'com': 361398,
#  'toprating': 3656,
#  'heard': 1364,
#  'there': 26078,
#  'guy': 13460,
#  'who': 18013,
#  'know': 20341,
#  'someone': 5194,
#  'think': 24419,
#  'somebody': 1100,
#  'something': 6050,
#  'on': 248231,
#  'stocktwits': 102558,
#  'reveal': 253,
#  'yourself': 1212,
#  'why': 23266,
#  'the': 407462,
#  'drop': 18237,
#  'warren': 1235,
#  'buffet': 1403,
#  'taking': 6542,
#  'out': 57439,
#  'his': 6365,
#  'position': 11954,
#  'bear': 33848,
#  'have': 53430,
#  'reason': 8062,
#  '06': 8782,
#  '29': 11027,
#  'to': 396240,
#  'pay': 7869,
#  'more': 56891,
#  'attention': 3565,
#  'dividendbot': 10212,
#  'ba': 1732,
#  'ok': 4586,
#  'good': 44611,
#  'we': 65083,
#  '39': 191102,
#  're': 13535,
#  'not': 69017,
#  'dropping': 2296,
#  'in': 212722,
#  'over': 48053,
#  'weekend': 3641,
#  'lol': 30934,
#  'daily': 16651,
#  'chart': 82668,
#  'need': 21939,
#  'get': 47407,
#  'back': 43474,
#  'above': 18390,
#  '50': 32520,
#  'per': 18946,
#  'week': 44980,
#  'after': 36187,
#  'spike': 2307,
#  'if': 59291,
#  'no': 41446,
#  'news': 50650,
#  'month': 16999,
#  '12': 24276,
#  'bo': 536,
#  'then': 21008,
#  'bingo': 181,
#  'what': 80211,
#  'odds': 407,
#  'strong': 17779,
#  'short': 87199,
#  'ratio': 8024,
#  '17': 22195,
#  '2018': 99721,
#  '15': 21455,
#  'and': 215121,
#  'float': 4686,
#  '42': 5853,
#  'sunshineavenue': 3602,
#  'stock': 103928,
#  'snp': 241,
#  'via': 23518,
#  'squeezing': 230,
#  'perfect': 2032,
#  'place': 2913,
#  'an': 23451,
#  'option': 23478,
#  'straddle': 2235,
#  'near': 6016,
#  'supporting': 293,
#  'trend': 8336,
#  'start': 9139,
#  'new': 49485,
#  'monday': 7697,
#  'expect': 10598,
#  'volume': 44512,
#  'across': 843,
#  'key': 34299,
#  'company': 24360,
#  'various': 86,
#  'sector': 5453,
#  'breakout': 6855,
#  'strategy': 1811,
#  'current': 6360,
#  'portfolio': 2681,
#  'bull': 27475,
#  'pfe': 1916,
#  'catalyst': 1325,
#  'continuing': 360,
#  'this': 204659,
#  'uptrend': 1721,
#  'pill': 201,
#  'pack': 202,
#  'amazon': 14436,
#  'prime': 2101,
#  'day': 68109,
#  'earnings': 58317,
#  'test': 4206,
#  'break': 17323,
#  '1763': 65,
#  'soon': 16291,
#  'ha': 45651,
#  'moved': 3388,
#  '21': 17936,
#  'check': 5538,
#  'movement': 3046,
#  'peer': 3267,
#  'aapl': 8569,
#  'mkm': 215,
#  'partner': 1700,
#  'set': 6724,
#  '91': 2714,
#  'it': 200144,
#  'too': 19197,
#  'early': 4918,
#  'tell': 4767,
#  'going': 48204,
#  'happen': 4293,
#  'even': 16010,
#  'about': 28417,
#  'raisinf': 1,
#  'output': 165,
#  'still': 35696,
#  'so': 46569,
#  'many': 9514,
#  '66': 4028,
#  'financially': 581,
#  'healthy': 1833,
#  'problem': 2902,
#  'meeting': 1131,
#  'obligation': 671,
#  'chartmill': 19522,
#  'analyze': 19561,
#  'php': 31695,
#  'utm': 305638,
#  'source': 111584,
#  'amp': 396007,
#  'medium': 95794,
#  'fa': 23334,
#  'content': 88642,
#  'health': 5564,
#  'campaign': 23832,
#  'social': 21331,
#  'tracking': 19533,
#  'nke': 2354,
#  '8832fee1': 182,
#  'd06b': 182,
#  '46b5': 182,
#  '827f': 184,
#  '26246a5e29a8': 182,
#  'bullish': 25952,
#  'watch': 18020,
#  'setup': 11686,
#  'timeframes': 41,
#  'seeitmarket': 229,
#  'twitter': 3279,
#  'twtr': 548,
#  'michael': 1365,
#  'kor': 1038,
#  '18140': 1,
#  'blog': 3058,
#  'by': 56586,
#  'just': 73718,
#  'high': 29408,
#  'alert': 19300,
#  'next': 47801,
#  'gt': 9715,
#  '14': 16725,
#  '40': 14872,
#  'breakdown': 1139,
#  'much': 16823,
#  'better': 14118,
#  'than': 29968,
#  'industry': 8283,
#  'average': 9853,
#  '71': 3954,
#  'fslr': 639,
#  'b431cf47': 56,
#  'ec7e': 56,
#  '4226': 67,
#  'b864': 56,
#  '511b6081b3be': 56,
#  'miss': 8700,
#  'these': 14496,
#  'confirms': 525,
#  'you': 95321,
#  'will': 129534,
#  'see': 45333,
#  'violent': 147,
#  'move': 23246,
#  'downward': 851,
#  'my': 51469,
#  'cv': 1653,
#  'base': 1523,
#  'gap': 9842,
#  '200': 11538,
#  'ma': 5450,
#  'cabot': 126,
#  'weekly': 7337,
#  'video': 4569,
#  'quot': 40004,
#  'resilient': 145,
#  'growth': 57943,
#  'bit': 11235,
#  'ly': 16648,
#  '2kj0fnd': 1,
#  'when': 30181,
#  'wa': 55429,
#  'kid': 1726,
#  'froend': 1,
#  'told': 3856,
#  'me': 26803,
#  'moon': 2274,
#  'made': 7935,
#  'cheese': 124,
#  'percent': 6791,
#  '35': 9301,
#  '28': 14784,
#  '18': 42758,
#  '20': 35647,
#  'rank': 5551,
#  '20th': 329,
#  'percentile': 1399,
#  'volumebot': 6752,
#  'uri': 490,
#  'thank': 4133,
#  'don': 25513,
#  'feel': 6020,
#  'or': 38871,
#  'do': 25170,
#  'well': 17038,
#  'they': 56518,
#  'already': 9714,
#  'during': 2641,
#  'youtube': 3234,
#  'interview': 705,
#  'mitch': 67,
#  'couldn': 1257,
#  'remember': 4831,
#  'single': 2331,
#  'movie': 953,
#  'he': 12134,
#  'watched': 400,
#  'all': 60815,
#  'year': 35322,
#  'except': 1142,
#  'star': 2555,
#  'war': 5727,
#  'black': 1373,
#  'panther': 26,
#  'clothes': 120,
#  'downgrade': 4587,
#  '38': 5710,
#  'sale': 38208,
#  'interest': 12701,
#  '43': 5560,
#  'shortvolumes': 6655,
#  'ntap': 455,
#  'return': 7287,
#  'equity': 10317,
#  '97': 3114,
#  'profitability': 5074,
#  'e4a695e1': 17,
#  'f0f2': 17,
#  '45d3': 18,
#  'b20c': 17,
#  '84c2169e9553': 17,
#  'although': 1868,
#  'market': 58463,
#  'up': 122936,
#  'doing': 5568,
#  'advanced': 1747,
#  '05': 7936,
#  'a': 48845,
#  'info': 4322,
#  'txn': 1259,
#  'july': 3800,
#  'be': 97354,
#  'most': 8744,
#  '5x': 441,
#  'normal': 1640,
#  'friday': 11427,
#  '154': 437,
#  '810': 97,
#  'contract': 14647,
#  'call': 69250,
#  'put': 37172,
#  '57': 5367,
#  'tinyurl': 8014,
#  'y7ue344l': 1,
#  'third': 2209,
#  'design': 686,
#  'win': 6401,
#  'timing': 675,
#  'match': 454,
#  'probably': 5084,
#  'arm': 348,
#  'forbes': 666,
#  'site': 1560,
#  'ewanspence': 4,
#  '30': 31168,
#  'surface': 271,
#  'andromeda': 7,
#  'windowsphone': 1,
#  'windows10': 3,
#  'tablet': 128,
#  'leak': 642,
#  'rumor': 1304,
#  'spec': 301,
#  'release': 7738,
#  'date': 10167,
#  '1d21bec34e96': 1,
#  'alcohol': 81,
#  'tobacco': 181,
#  'firearm': 3,
#  'chc': 59,
#  'li': 143,
#  '2kdqyur': 1,
#  'president': 3103,
#  'trump': 13148,
#  'tweet': 3240,
#  'spoke': 174,
#  'king': 1367,
#  'salman': 8,
#  'saudi': 984,
#  'arabia': 239,
#  'explained': 126,
#  'him': 2113,
#  'that': 90412,
#  'because': 8010,
#  'turmoil': 143,
#  'today': 76718,
#  'insight': 8709,
#  'app': 15993,
#  'seasonaledge': 9109,
#  'tool': 9731,
#  'tap': 994,
#  'intc': 4288,
#  'mama': 154,
#  'said': 9658,
#  'ice': 784,
#  'cream': 119,
#  'finish': 1177,
#  'due': 3921,
#  'dil': 3,
#  'noticed': 365,
#  'last': 38105,
#  'jedi': 193,
#  'stream': 637,
#  'love': 10502,
#  'here': 75661,
#  'go': 53151,
#  'leave': 1394,
#  'view': 5424,
#  'look': 31851,
#  '5ema': 8,
#  'held': 2840,
#  '20ema': 99,
#  'stochastics': 73,
#  'turning': 1196,
#  'spy': 2251,
#  'qqq': 676,
#  'opposite': 877,
#  'forward': 3458,
#  'pe': 4461,
#  '75': 8407,
#  'valuation': 6858,
#  'can': 44798,
#  'described': 346,
#  'cheap': 7979,
#  'mu': 11991,
#  '1852fbab': 379,
#  'a521': 379,
#  '4084': 382,
#  'b2cf': 379,
#  '8f89daf57241': 379,
#  'saber': 17,
#  'capital': 3723,
#  'presentation': 713,
#  'common': 1579,
#  'denominator': 13,
#  'tencent': 212,
#  'facebook': 11932,
#  'google': 5927,
#  'investoralmanac': 405,
#  '11': 30302,
#  'how': 25529,
#  'one': 28067,
#  'performing': 992,
#  'crude': 721,
#  'petroleum': 313,
#  'natural': 807,
#  'gas': 1963,
#  'ta': 12084,
#  'dnr': 875,
#  '390f838e': 116,
#  'f784': 116,
#  '423a': 117,
#  '8673': 116,
#  '94476a9ff4aa': 116,
#  'pu': 53,
#  'simply': 639,
#  'havent': 216,
#  'lost': 4599,
#  'any': 14361,
#  'brown': 268,
#  'run': 16012,
#  'tech': 11225,
#  'mf': 310,
#  'are': 102862,
#  'educated': 115,
#  'their': 24556,
#  'shit': 6414,
#  'every': 8863,
#  'former': 527,
#  'global': 3170,
#  'manufacturing': 461,
#  'pfizer': 642,
#  'independent': 207,
#  'director': 5591,
#  'nat': 141,
#  'ricciardi': 4,
#  'may': 11778,
#  'safest': 157,
#  'special': 679,
#  'limited': 639,
#  'offer': 1870,
#  'june': 1415,
#  '14th': 101,
#  '30th': 225,
#  'tradenet': 6,
#  'offering': 844,
#  'discount': 1515,
#  'intro': 65699,
#  'program': 1227,
#  'limitedtime': 1,
#  'id': 11127,
#  '7010o000001pnwd': 1,
#  'affiliateorg': 1,
#  'affiliateid': 1,
#  '36619': 2,
#  'affiliatedata': 1,
#  '451595': 1,
#  'below': 11539,
#  'financials': 1169,
#  'summary': 5734,
#  'jeff': 803,
#  'gundlach': 63,
#  'sohn': 25,
#  'long': 32879,
#  'thesis': 1023,
#  'energy': 4067,
#  '04': 4962,
#  'jeffrey': 305,
#  'low': 24575,
#  'peg': 746,
#  'which': 8294,
#  'compensates': 296,
#  'indicates': 1998,
#  'rather': 2374,
#  'hpq': 451,
#  '87d9930a': 25,
#  '9d05': 25,
#  '4a11': 29,
#  '9ac9': 25,
#  'e9954e349fe5': 25,
#  'pres': 356,
#  'coming': 19206,
#  'seems': 5417,
#  'support': 17642,
#  '25': 28227,
#  'under': 9320,
#  'likely': 3774,
#  '53': 5523,
#  'wba': 684,
#  'bullshit': 874,
#  'worthless': 1029,
#  'mean': 6328,
#  'fucking': 2388,
#  'nothing': 7047,
#  'macau': 341,
#  'usa': 1245,
#  'take': 18352,
#  'let': 27041,
#  'where': 12538,
#  'right': 19313,
#  'now': 58453,
#  'ugly': 1867,
#  'without': 2411,
#  'clear': 2712,
#  'level': 9780,
#  'term': 21327,
#  'bearish': 11838,
#  'll': 13151,
#  'previously': 2043,
#  'mo': 1631,
#  'followed': 986,
#  'end': 16240,
#  'another': 14267,
#  'runup': 191,
#  'dropped': 2976,
#  '10': 93956,
#  'smart': 3457,
#  'money': 25490,
#  'betting': 936,
#  'deal': 7688,
#  'update': 37352,
#  'uk': 912,
#  'reuters': 1167,
#  'article': 13672,
#  'indonesia': 108,
#  'rio': 67,
#  'tinto': 7,
#  'grasberg': 37,
#  'inalum': 10,
#  'close': 29696,
#  'acquiring': 128,
#  'copper': 370,
#  'mine': 626,
#  'official': 571,
#  'idukkbn1jq05h': 1,
#  'technical': 15149,
#  'bad': 13395,
#  'doe': 11305,
#  'present': 2614,
#  'nice': 17348,
#  'opportunity': 6124,
#  'wynn': 2065,
#  '5f008ceb': 96,
#  '7e89': 96,
#  '4999': 102,
#  'a2da': 96,
#  'c893680bc755': 96,
#  'completely': 1044,
#  'scale': 403,
#  'time': 54803,
#  'gobble': 107,
#  'play': 9676,
#  'aka': 337,
#  'favorite': 935,
#  'pwr': 187,
#  'them': 11111,
#  'iddy': 1,
#  'bitty': 10,
#  'kiddy': 33,
#  'hand': 3799,
#  '77': 3904,
#  'urbn': 876,
#  'awesome': 1852,
#  'concerned': 559,
#  'eow': 2107,
#  'might': 9073,
#  'wk': 723,
#  'throwback': 63,
#  'u': 23908,
#  'advisor': 299,
#  'upgrade': 7209,
#  'shorties': 809,
#  'dreaming': 232,
#  'depression': 150,
#  'somethin': 27,
#  'loll': 48,
#  'updated': 909,
#  'hormel': 162,
#  'food': 1821,
#  'dividend': 9785,
#  'analysis': 9691,
#  'dividendvaluebuilder': 546,
#  'hrl': 330,
#  'consumer': 2546,
#  'defensive': 303,
#  'dal': 1444,
#  'intel': 10073,
#  'safety': 1430,
#  'score': 2762,
#  'technology': 5005,
#  'mpc': 427,
#  'both': 6283,
#  'positive': 9323,
#  'looking': 18038,
#  'chk': 1814,
#  '4df21b39': 173,
#  'cb5c': 173,
#  '41b6': 173,
#  '88a7': 173,
#  'ddbd28711da9': 173,
#  'mad': 1267,
#  'report': 68956,
#  'block': 10005,
#  'person': 707,
#  'spam': 282,
#  'should': 24602,
#  'open': 21908,
#  '400': 4252,
#  'projection': 286,
#  'thats': 2276,
#  'true': 2272,
#  'prefer': 366,
#  'from': 65887,
#  'turd': 1079,
#  '89': 3066,
#  'wal': 147,
#  'mart': 172,
#  'aristocrat': 331,
#  'wmt': 2146,
#  'valueinvesting': 53,
#  'dvb': 22,
#  'aaamp': 28,
#  'marriage': 40,
#  '2m': 1238,
#  'bank': 8508,
#  'account': 2952,
#  'dm': 63,
#  '60': 11469,
#  '52': 10841,
#  'alk': 514,
#  'won': 5487,
#  'stop': 12971,
#  'posting': 1303,
#  'holding': 15279,
#  'big': 29375,
#  'calm': 934,
#  'down': 69896,
#  'luck': 3428,
#  'chase': 1456,
#  'continues': 2788,
#  'hopefully': 2618,
#  'catch': 1777,
#  'before': 26095,
#  'lisa': 3172,
#  'announces': 4391,
#  '3rd': 1241,
#  'bbby': 907,
#  'f2bb9afa': 44,
#  'b79e': 44,
#  '4ecc': 44,
#  'ace1': 44,
#  '4be77006d5e1': 44,
#  'permamently': 1,
#  'turned': 1380,
#  'off': 21795,
#  'trading': 24138,
#  'maybe': 7832,
#  'altogether': 26,
#  'manipulation': 2569,
#  'very': 20134,
#  'rich': 1646,
#  'make': 20465,
#  'poor': 1916,
#  'fuk': 226,
#  'almost': 5658,
#  'pct': 728,
#  'buyback': 5270,
#  'got': 16288,
#  '4993': 1,
#  'share': 51554,
#  'though': 4130,
#  'drip': 323,
#  '017': 25,
#  '81': 3415,
#  '19': 21752,
#  'y88m4ukn': 1,
#  'hollywoodreporter': 14,
#  'thr': 57,
#  'esq': 4,
#  'netflix': 6701,
#  'green': 18459,
#  'light': 1417,
#  'appeal': 417,
#  'court': 736,
#  'challenge': 672,
#  'fox': 960,
#  'employment': 95,
#  '1124206': 1,
#  'sailthru': 1,
#  'email': 790,
#  'breaking': 3180,
#  '3a57': 1,
#  '3a38': 1,
#  'ehayden': 1,
#  'breakingnews': 4,
#  'dumped': 1082,
#  'obv': 180,
#  'but': 54088,
#  'jeez': 339,
#  'done': 5522,
#  'bounce': 11696,
#  'heikin': 10,
#  'ashi': 12,
#  'candle': 3287,
#  'confirmation': 743,
#  'liking': 419,
#  'wife': 661,
#  'tree': 569,
#  'fiddy': 32,
#  'sure': 8351,
#  'piggy': 270,
#  'lot': 10106,
#  'coin': 410,
#  'spend': 852,
#  'candy': 113,
#  '23': 14218,
#  '76': 3325,
#  'hban': 394,
#  'microsoft': 2930,
#  'msft': 4400,
#  'investor': 10311,
#  'aren': 1695,
#  'happy': 4381,
#  'shortpainbot': 3594,
#  'shld': 717,
#  'royal': 459,
#  'canada': 1572,
#  'reiterates': 1921,
#  'outperform': 2028,
#  'loop': 354,
#  'raise': 7696,
#  '80': 9639,
#  'never': 9060,
#  'been': 19951,
#  'wrong': 5720,
#  'miracle': 317,
#  '8o': 1,
#  'period': 1206,
#  'bollinger': 1505,
#  'band': 1686,
#  'dare': 355,
#  'say': 18472,
#  'didn': 5932,
#  'guilty': 106,
#  'fudge': 65,
#  'cvx': 648,
#  'hardly': 255,
#  'ever': 5711,
#  'informative': 33,
#  'comment': 2637,
#  'page': 1401,
#  'broken': 1612,
#  'giving': 1817,
#  'endless': 234,
#  'buffering': 4,
#  'icon': 201,
#  'give': 7918,
#  'viral': 22,
#  'walk': 1129,
#  'away': 4905,
#  'highlight': 376,
#  'growing': 2362,
#  'democrat': 297,
#  'leaving': 925,
#  'party': 1775,
#  'epoch': 2,
#  'theepochtimes': 5,
#  '2578446': 1,
#  'html': 26142,
#  'robert': 1037,
#  'baird': 818,
#  'neutral': 3793,
#  'weed': 757,
#  'other': 8683,
#  'drug': 1570,
#  'guess': 5929,
#  'reasonable': 621,
#  'd4067eb8': 49,
#  '9699': 51,
#  '411d': 50,
#  'ab3c': 49,
#  '8591fd573a1a': 49,
#  'nike': 4593,
#  'winning': 2183,
#  'click': 1538,
#  'booking': 1337,
#  'native': 22,
#  'seamless': 13,
#  'lovalized': 1,
#  'transactable': 1,
#  'ap': 101,
#  'vitiello': 1,
#  'tapped': 128,
#  'acting': 774,
#  'hvper': 9871,
#  'ref': 10884,
#  'stw': 9871,
#  'reach': 2196,
#  '100': 14983,
#  'iconic': 79,
#  'brand': 2488,
#  'built': 483,
#  'mobile': 1433,
#  'show': 10149,
#  '13': 18330,
#  '74': 3464,
#  'morning': 11459,
#  'heading': 2824,
#  'ath': 3145,
#  '65': 6638,
#  'acquisition': 2180,
#  'total': 7861,
#  '500': 6037,
#  'past': 8365,
#  'adi': 396,
#  'exit': 1526,
#  'zone': 1622,
#  'sputniknews': 11,
#  'middleeast': 8,
#  '201807011065929124': 1,
#  'wont': 1617,
#  'promise': 473,
#  'oil': 6051,
#  'fantastic': 582,
#  'read': 3912,
#  'tighten': 371,
#  'bbl': 149,
#  'getting': 12494,
#  'closer': 1183,
#  '02': 8045,
#  'greatest': 432,
#  'yearly': 1240,
#  'performance': 2428,
#  'did': 12736,
#  '98': 3052,
#  'fosl': 437,
#  '195c7be0': 23,
#  '5092': 23,
#  '4f1c': 23,
#  '9083': 23,
#  '62f56f783cdf': 23,
#  'att': 541,
#  'champion': 204,
#  'cashflow': 75,
#  'highyield': 23,
#  'telecommunication': 17,
#  'pretty': 4514,
#  'risky': 740,
#  'gamble': 908,
#  'either': 3238,
#  'plummet': 348,
#  'rally': 6570,
#  'mdlz': 494,
#  'stronger': 889,
#  'apple': 16727,
#  'talking': 2781,
#  'referring': 108,
#  'intelsat': 8,
#  'punish': 129,
#  'seller': 3191,
#  'warehouse': 115,
#  'sense': 2230,
#  'old': 3914,
#  'gather': 176,
#  'dust': 450,
#  'pc': 875,
#  'gamers': 236,
#  'crypto': 1875,
#  'miner': 193,
#  'gpu': 1549,
#  'enthusiast': 33,
#  'waiting': 7269,
#  'two': 5882,
#  'cnet': 111,
#  'nvidia': 4201,
#  'geforce': 228,
#  'gtx': 156,
#  '1180s': 5,
#  'leaked': 444,
#  'only': 19148,
#  'decent': 2935,
#  'pattern': 6710,
#  'mnk': 509,
#  'd857317a': 61,
#  'd94c': 63,
#  '4373': 69,
#  'adc3': 62,
#  '9cbe67b2f3fb': 61,
#  'dvn': 483,
#  'five': 892,
#  'baba': 614,
#  '190': 2414,
#  'ahhhhhhhhhhhhhhhhhhhhh': 1,
#  'nem': 357,
#  'raytheon': 273,
#  'rtn': 613,
#  'industrials': 329,
#  'military': 398,
#  'trending': 2009,
#  'riiiiiiiiiich': 1,
#  'sooooon': 11,
#  'buuuuls': 1,
#  'looooove': 4,
#  'drunk': 211,
#  'doesn': 6313,
#  'through': 6269,
#  '32': 10087,
#  'gapping': 286,
#  '54': 4986,
#  'chrw': 250,
#  '64': 4388,
#  'warbey': 1,
#  'parker': 238,
#  '8b': 223,
#  'prep': 116,
#  'glass': 332,
#  'seen': 3994,
#  'focus': 1292,
#  'fashion': 252,
#  'wrt': 16,
#  'wearable': 124,
#  'like': 52236,
#  'sbux': 2008,
#  'paying': 1573,
#  'full': 3149,
#  'sex': 206,
#  'change': 20582,
#  'employee': 1273,
#  'hit': 13065,
#  'bottom': 9821,
#  'line': 7502,
#  'recap': 1507,
#  '63': 3822,
#  'since': 22818,
#  'post': 14019,
#  '62': 4375,
#  'trade': 52644,
#  'included': 381,
#  'hsy': 389,
#  'sonc': 11,
#  'dri': 882,
#  'kmx': 783,
#  'akam': 477,
#  'enterprise': 2114,
#  'value': 6026,
#  'v': 5960,
#  'cap': 4402,
#  '21b': 38,
#  'difference': 10106,
#  'actual': 651,
#  'asset': 2069,
#  'spread': 2497,
#  'way': 16824,
#  'undervalued': 2610,
#  'million': 6940,
#  'added': 5605,
#  'dont': 6401,
#  'become': 1726,
#  'such': 2920,
#  'monopoly': 340,
#  'dipping': 309,
#  'into': 17826,
#  'everything': 4329,
#  'airline': 1209,
#  'possibility': 479,
#  'loss': 8182,
#  '95': 4707,
#  'suggested': 324,
#  'analyzer': 521,
#  ...}

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the number of messages. Then remove words that only appear in some small fraction of the messages.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs = {word : count / len(bow) for word, count in bow.items()}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 1e-5

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 10

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = [common[0] for common in bow_list.most_common(high_cutoff)]


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# ['http', 'the', 'to', 'amp', 'com', 'utm', 'is', 'for', 'on', 'www']
# 61533

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

#TODO Implement

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = {word : index for index, word in enumerate(filtered_words, 1)}

# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = {index :  word for word, index in vocab.items()}

# tokenized with the words not in `filtered_words` removed.
filtered = [[word for word in message if word in vocab] for message in tokenized]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.19563799174677293

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
        # Setup additional layers
        self.lstm = nn.LSTM(
            embed_size,
            lstm_size,
            lstm_layers,
            dropout = dropout,
            batch_first = False
        )
        self.dropout = nn.Dropout(dropout)
        self.fc      = nn.Linear(lstm_size, output_size)
        self.log_softmax = nn.LogSoftmax( dim = 1 )


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # TODO Implement 
        
        weight = next(self.parameters()).data
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        
        return (
            weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_(),
            weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_()
        )


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        
        embeds = self.embedding(nn_input.long())
        lstm_output, hidden = self.lstm(embeds, hidden_state)
        lstm_output = lstm_output[-1, : , :]
        
        out = self.fc(
            self.dropout(lstm_output)
        )
        
        
        return self.log_softmax(out), hidden

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.2567, -1.8630, -1.6422, -1.6953, -1.6978],
#         [-1.3471, -1.8291, -1.6430, -1.7104, -1.5835],
#         [-1.3657, -1.8009, -1.6078, -1.6939, -1.6321],
#         [-1.3357, -1.8230, -1.6393, -1.7153, -1.6021]])

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

split_idx = int(len(token_ids) * 0.8)

train_features = token_ids[:split_idx]
valid_features = token_ids[split_idx:]
train_labels = sentiments[:split_idx]
valid_labels = sentiments[split_idx:]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(61534, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (log_softmax): LogSoftmax()
# )

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""
import numpy as np

epochs = 5
batch_size = 512
learning_rate = .01

print_every = 100
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    
    steps = 0
    for text_batch, labels in dataloader(
            train_features, train_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
        steps += 1
        hidden = model.init_hidden(labels.shape[0])
        
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        
        model.zero_grad()
        # TODO Implement: Train Model
        output, hidden = model(text_batch, hidden)
        
        loss = criterion(output.squeeze(), labels)
        loss.backward()
        
        optimizer.step()
        
        if steps % print_every == 0:
            model.eval()
            
            # TODO Implement: Print metrics
            validation_losses = []
            accuracy = []
            for validation_text_batch, validation_labels in dataloader(valid_features, valid_labels, batch_size = batch_size) :
                validation_text_batch = validation_text_batch.to(device)
                validation_labels     = validation_labels.to(device)
                
                validation_hidden = model.init_hidden(validation_labels.shape[0])
                for hid in hidden:
                    hid = hid.to(device)
                    
                
                validation_output, validation_hidden = model(validation_text_batch, validation_hidden)
                
                
                validation_loss = criterion(validation_output.squeeze(), validation_labels)
                validation_losses.append(validation_loss.item())
            
                ps = torch.exp(validation_output)
                top_p, top_class = ps.topk(1, dim = 1)
                equals = (top_class == validation_labels.view(*top_class.shape))
                accuracy.append(
                    torch.mean(
                        equals.type(torch.FloatTensor)
                    ).item()
                )
            
            model.train()
            print("Epoch : {}/{}...".format(epoch + 1, epochs),
                  "Step  : {}...".format(steps),
                  "Neg. Log Likelihood Loss : {}...".format(loss.item()),
                  "Validation Loss          : {}...".format(np.mean(validation_losses)),
                  "Validation Accuracy      : {}...".format(np.mean(accuracy))
                 )
# Out:
# Starting epoch 1
# Epoch : 1/5... Step  : 100... Neg. Log Likelihood Loss : 1.011291265487671... Validation Loss          : 1.0188031917122131... Validation Accuracy      : 0.5952361769406743...
# Epoch : 1/5... Step  : 200... Neg. Log Likelihood Loss : 0.856014609336853... Validation Loss          : 0.8839006450310972... Validation Accuracy      : 0.6535946679935408...
# Epoch : 1/5... Step  : 300... Neg. Log Likelihood Loss : 0.7982051372528076... Validation Loss          : 0.8544649295783453... Validation Accuracy      : 0.6685770394175293...
# Epoch : 1/5... Step  : 400... Neg. Log Likelihood Loss : 0.8037929534912109... Validation Loss          : 0.8318093896497966... Validation Accuracy      : 0.6785768607324698...
# Epoch : 1/5... Step  : 500... Neg. Log Likelihood Loss : 0.8531273603439331... Validation Loss          : 0.8194541063443449... Validation Accuracy      : 0.683454666881655...
# Epoch : 1/5... Step  : 600... Neg. Log Likelihood Loss : 0.768912672996521... Validation Loss          : 0.8025754868837773... Validation Accuracy      : 0.6900209813797503...
# Epoch : 1/5... Step  : 700... Neg. Log Likelihood Loss : 0.8045396208763123... Validation Loss          : 0.7897847301397628... Validation Accuracy      : 0.6943550083502504...
# Epoch : 1/5... Step  : 800... Neg. Log Likelihood Loss : 0.7157869338989258... Validation Loss          : 0.7902190057739286... Validation Accuracy      : 0.6930205176151941...
# Epoch : 1/5... Step  : 900... Neg. Log Likelihood Loss : 0.7637460827827454... Validation Loss          : 0.7811716087620147... Validation Accuracy      : 0.6970914389928963...
# Epoch : 1/5... Step  : 1000... Neg. Log Likelihood Loss : 0.7756779193878174... Validation Loss          : 0.7807814549901855... Validation Accuracy      : 0.6983247390543214...
# Epoch : 1/5... Step  : 1100... Neg. Log Likelihood Loss : 0.7729959487915039... Validation Loss          : 0.7787387412801129... Validation Accuracy      : 0.6981323705551372...
# Epoch : 1/5... Step  : 1200... Neg. Log Likelihood Loss : 0.7792285084724426... Validation Loss          : 0.7745781434695317... Validation Accuracy      : 0.7007961380100953...
# Epoch : 1/5... Step  : 1300... Neg. Log Likelihood Loss : 0.7860826849937439... Validation Loss          : 0.7682063173896264... Validation Accuracy      : 0.7036824284958898...
# Epoch : 1/5... Step  : 1400... Neg. Log Likelihood Loss : 0.7871292233467102... Validation Loss          : 0.7813653017437722... Validation Accuracy      : 0.69658276270297...
# Epoch : 1/5... Step  : 1500... Neg. Log Likelihood Loss : 0.8035497665405273... Validation Loss          : 0.7662779127936399... Validation Accuracy      : 0.7046112101845425...
# Epoch : 1/5... Step  : 1600... Neg. Log Likelihood Loss : 0.75740647315979... Validation Loss          : 0.7698374567072866... Validation Accuracy      : 0.7014856588928354...
# Starting epoch 2
# Epoch : 2/5... Step  : 100... Neg. Log Likelihood Loss : 0.7185995578765869... Validation Loss          : 0.7720369629982942... Validation Accuracy      : 0.7046234147847431...
# Epoch : 2/5... Step  : 200... Neg. Log Likelihood Loss : 0.7908468842506409... Validation Loss          : 0.7645630017106012... Validation Accuracy      : 0.7062029116569631...
# Epoch : 2/5... Step  : 300... Neg. Log Likelihood Loss : 0.6695629954338074... Validation Loss          : 0.7754915513336219... Validation Accuracy      : 0.7013608892368157...
# Epoch : 2/5... Step  : 400... Neg. Log Likelihood Loss : 0.7444275617599487... Validation Loss          : 0.7724166171263711... Validation Accuracy      : 0.7001334838843756...
# Epoch : 2/5... Step  : 500... Neg. Log Likelihood Loss : 0.7733849287033081... Validation Loss          : 0.7675088296944151... Validation Accuracy      : 0.7061583606265394...
# Epoch : 2/5... Step  : 600... Neg. Log Likelihood Loss : 0.7266064286231995... Validation Loss          : 0.7609075125517365... Validation Accuracy      : 0.7087840029297062...
# Epoch : 2/5... Step  : 700... Neg. Log Likelihood Loss : 0.7585264444351196... Validation Loss          : 0.7592277176842935... Validation Accuracy      : 0.7104710003667734...
# Epoch : 2/5... Step  : 800... Neg. Log Likelihood Loss : 0.7259264588356018... Validation Loss          : 0.763203763258838... Validation Accuracy      : 0.7084875713109384...
# Epoch : 2/5... Step  : 900... Neg. Log Likelihood Loss : 0.7102073431015015... Validation Loss          : 0.7586749593660931... Validation Accuracy      : 0.709021337641545...
# Epoch : 2/5... Step  : 1000... Neg. Log Likelihood Loss : 0.7488869428634644... Validation Loss          : 0.7623630632493068... Validation Accuracy      : 0.7097533671803204...
# Epoch : 2/5... Step  : 1100... Neg. Log Likelihood Loss : 0.6724948883056641... Validation Loss          : 0.7619158097654947... Validation Accuracy      : 0.7082365209406073...
# Epoch : 2/5... Step  : 1200... Neg. Log Likelihood Loss : 0.7717258930206299... Validation Loss          : 0.7603052388098668... Validation Accuracy      : 0.7059681840259261...
# Epoch : 2/5... Step  : 1300... Neg. Log Likelihood Loss : 0.788328230381012... Validation Loss          : 0.7570816115899519... Validation Accuracy      : 0.7082092390013561...
# Epoch : 2/5... Step  : 1400... Neg. Log Likelihood Loss : 0.7383382320404053... Validation Loss          : 0.7569130741114698... Validation Accuracy      : 0.7109896893583293...
# Epoch : 2/5... Step  : 1500... Neg. Log Likelihood Loss : 0.7716994285583496... Validation Loss          : 0.7572663708313091... Validation Accuracy      : 0.7051929648443873...
# Epoch : 2/5... Step  : 1600... Neg. Log Likelihood Loss : 0.7212005853652954... Validation Loss          : 0.7572399988514199... Validation Accuracy      : 0.7110830590824531...
# Starting epoch 3
# Epoch : 3/5... Step  : 100... Neg. Log Likelihood Loss : 0.7686898112297058... Validation Loss          : 0.7589760335569593... Validation Accuracy      : 0.709158727079996...
# Epoch : 3/5... Step  : 200... Neg. Log Likelihood Loss : 0.733059287071228... Validation Loss          : 0.7610254890356368... Validation Accuracy      : 0.7112926966728098...
# Epoch : 3/5... Step  : 300... Neg. Log Likelihood Loss : 0.6852313280105591... Validation Loss          : 0.7568009257755935... Validation Accuracy      : 0.7102738330346653...
# Epoch : 3/5... Step  : 400... Neg. Log Likelihood Loss : 0.7045769095420837... Validation Loss          : 0.7592228390367962... Validation Accuracy      : 0.7052442409482577...
# Epoch : 3/5... Step  : 500... Neg. Log Likelihood Loss : 0.7821843028068542... Validation Loss          : 0.7606367322385165... Validation Accuracy      : 0.7063387900371223...
# Epoch : 3/5... Step  : 600... Neg. Log Likelihood Loss : 0.830435574054718... Validation Loss          : 0.7582087584151097... Validation Accuracy      : 0.7105791816254505...
# Epoch : 3/5... Step  : 700... Neg. Log Likelihood Loss : 0.8275890946388245... Validation Loss          : 0.7548792311688313... Validation Accuracy      : 0.708128754717712...
# Epoch : 3/5... Step  : 800... Neg. Log Likelihood Loss : 0.7078081965446472... Validation Loss          : 0.7576878819916699... Validation Accuracy      : 0.7110538509026793...
# Epoch : 3/5... Step  : 900... Neg. Log Likelihood Loss : 0.7442625761032104... Validation Loss          : 0.7600437281904994... Validation Accuracy      : 0.7106189338229505...
# Epoch : 3/5... Step  : 1000... Neg. Log Likelihood Loss : 0.7493550181388855... Validation Loss          : 0.7691356831159287... Validation Accuracy      : 0.705862194519371...
# Epoch : 3/5... Step  : 1100... Neg. Log Likelihood Loss : 0.7551363110542297... Validation Loss          : 0.7549003552306782... Validation Accuracy      : 0.7119933262796894...
# Epoch : 3/5... Step  : 1200... Neg. Log Likelihood Loss : 0.7280857563018799... Validation Loss          : 0.7670427997955819... Validation Accuracy      : 0.6948595665010832...
# Epoch : 3/5... Step  : 1300... Neg. Log Likelihood Loss : 0.8069777488708496... Validation Loss          : 0.7508233276719836... Validation Accuracy      : 0.7138301834134564...
# Epoch : 3/5... Step  : 1400... Neg. Log Likelihood Loss : 0.738985002040863... Validation Loss          : 0.7489863600426283... Validation Accuracy      : 0.7142967660831292...
# Epoch : 3/5... Step  : 1500... Neg. Log Likelihood Loss : 0.7656291723251343... Validation Loss          : 0.7486715493975459... Validation Accuracy      : 0.7135455412126583...
# Epoch : 3/5... Step  : 1600... Neg. Log Likelihood Loss : 0.811198353767395... Validation Loss          : 0.7531320431455054... Validation Accuracy      : 0.7048644524534445...
# Starting epoch 4
# Epoch : 4/5... Step  : 100... Neg. Log Likelihood Loss : 0.7816947102546692... Validation Loss          : 0.7556049438600752... Validation Accuracy      : 0.7127035535524167...
# Epoch : 4/5... Step  : 200... Neg. Log Likelihood Loss : 0.7034692764282227... Validation Loss          : 0.7558933743973621... Validation Accuracy      : 0.7137671177451675...
# Epoch : 4/5... Step  : 300... Neg. Log Likelihood Loss : 0.7302076816558838... Validation Loss          : 0.7578768503167999... Validation Accuracy      : 0.7142337004148404...
# Epoch : 4/5... Step  : 400... Neg. Log Likelihood Loss : 0.7251308560371399... Validation Loss          : 0.7523398709824396... Validation Accuracy      : 0.7144219509213797...
# Epoch : 4/5... Step  : 500... Neg. Log Likelihood Loss : 0.7412796020507812... Validation Loss          : 0.7554232520611924... Validation Accuracy      : 0.711232918779153...
# Epoch : 4/5... Step  : 600... Neg. Log Likelihood Loss : 0.7534366846084595... Validation Loss          : 0.7563338594588952... Validation Accuracy      : 0.7118600548338831...
# Epoch : 4/5... Step  : 700... Neg. Log Likelihood Loss : 0.79920893907547... Validation Loss          : 0.753531101514432... Validation Accuracy      : 0.7130217875836815...
# Epoch : 4/5... Step  : 800... Neg. Log Likelihood Loss : 0.7365421652793884... Validation Loss          : 0.7599197179445177... Validation Accuracy      : 0.7087231291599883...
# Epoch : 4/5... Step  : 900... Neg. Log Likelihood Loss : 0.7675484418869019... Validation Loss          : 0.7562016003401332... Validation Accuracy      : 0.7127862295881829...
# Epoch : 4/5... Step  : 1000... Neg. Log Likelihood Loss : 0.7803727388381958... Validation Loss          : 0.7552168035390043... Validation Accuracy      : 0.7139475471557505...
# Epoch : 4/5... Step  : 1100... Neg. Log Likelihood Loss : 0.7528071999549866... Validation Loss          : 0.7610278842050847... Validation Accuracy      : 0.7099863182414662...
# Epoch : 4/5... Step  : 1200... Neg. Log Likelihood Loss : 0.7886987924575806... Validation Loss          : 0.7565218179466098... Validation Accuracy      : 0.7130674346366151...
# Epoch : 4/5... Step  : 1300... Neg. Log Likelihood Loss : 0.8732355833053589... Validation Loss          : 0.7540604345482164... Validation Accuracy      : 0.7152251327359999...
# Epoch : 4/5... Step  : 1400... Neg. Log Likelihood Loss : 0.8094982504844666... Validation Loss          : 0.7606330904972348... Validation Accuracy      : 0.7029599964765132...
# Epoch : 4/5... Step  : 1500... Neg. Log Likelihood Loss : 0.6972633600234985... Validation Loss          : 0.7611063669003199... Validation Accuracy      : 0.7117005974713356...
# Epoch : 4/5... Step  : 1600... Neg. Log Likelihood Loss : 0.7296806573867798... Validation Loss          : 0.7641548255151847... Validation Accuracy      : 0.7104112224731164...
# Starting epoch 5
# Epoch : 5/5... Step  : 100... Neg. Log Likelihood Loss : 0.7229914665222168... Validation Loss          : 0.7571524539069989... Validation Accuracy      : 0.7132044088928354...
# Epoch : 5/5... Step  : 200... Neg. Log Likelihood Loss : 0.7207076549530029... Validation Loss          : 0.7563628197009206... Validation Accuracy      : 0.7094159378173603...
# Epoch : 5/5... Step  : 300... Neg. Log Likelihood Loss : 0.7650048136711121... Validation Loss          : 0.7597329897728248... Validation Accuracy      : 0.7048976291016806...
# Epoch : 5/5... Step  : 400... Neg. Log Likelihood Loss : 0.7118841409683228... Validation Loss          : 0.75804836634336... Validation Accuracy      : 0.7135204510255293...
# Epoch : 5/5... Step  : 500... Neg. Log Likelihood Loss : 0.7572795152664185... Validation Loss          : 0.7597730392613048... Validation Accuracy      : 0.7116371167672647...
# Epoch : 5/5... Step  : 600... Neg. Log Likelihood Loss : 0.6934207677841187... Validation Loss          : 0.7660692632198334... Validation Accuracy      : 0.7100225170062859...
# Epoch : 5/5... Step  : 700... Neg. Log Likelihood Loss : 0.7143039703369141... Validation Loss          : 0.7650264224051258... Validation Accuracy      : 0.7120347390596639...
# Epoch : 5/5... Step  : 800... Neg. Log Likelihood Loss : 0.7968575358390808... Validation Loss          : 0.7632194963222054... Validation Accuracy      : 0.7090387562569002...
# Epoch : 5/5... Step  : 900... Neg. Log Likelihood Loss : 0.7678085565567017... Validation Loss          : 0.7601678400719195... Validation Accuracy      : 0.7079442071680355...
# Epoch : 5/5... Step  : 1000... Neg. Log Likelihood Loss : 0.7362446188926697... Validation Loss          : 0.761704688136642... Validation Accuracy      : 0.7077810468486252...
# Epoch : 5/5... Step  : 1100... Neg. Log Likelihood Loss : 0.7853306531906128... Validation Loss          : 0.7603987290613189... Validation Accuracy      : 0.7108176122133504...
# Epoch : 5/5... Step  : 1200... Neg. Log Likelihood Loss : 0.7849420309066772... Validation Loss          : 0.7629249379295097... Validation Accuracy      : 0.7039500671171146...
# Epoch : 5/5... Step  : 1300... Neg. Log Likelihood Loss : 0.7526992559432983... Validation Loss          : 0.7617050065894677... Validation Accuracy      : 0.7051929648443873...
# Epoch : 5/5... Step  : 1400... Neg. Log Likelihood Loss : 0.7913610935211182... Validation Loss          : 0.7595109861957353... Validation Accuracy      : 0.7107349361775841...
# Epoch : 5/5... Step  : 1500... Neg. Log Likelihood Loss : 0.714497983455658... Validation Loss          : 0.7600655534490027... Validation Accuracy      : 0.7109360719781543...
# Epoch : 5/5... Step  : 1600... Neg. Log Likelihood Loss : 0.7740300893783569... Validation Loss          : 0.7621574492653699... Validation Accuracy      : 0.7085370706984686...

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    # TODO Implement
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [token for token in tokens if token in vocab]
    
    # Convert words to ids
    tokens = [vocab[token] for token in tokens]
        
    # Adding a batch dimension
    text_input = torch.from_numpy(
        np.asarray(
            torch.FloatTensor(tokens).view(-1, 1)
        )
    )
    
    # Get the NN output
    hidden   = model.init_hidden(1)
    
    logps, _ = model.forward(text_input, hidden)
    
    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = torch.exp(logps)
    
    return pred

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# tensor([[ 0.0002,  0.0091,  0.0080,  0.8013,  0.1815]])

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
#
# The prediction is that there is an 80% accuracy of the model. That also means that the uncertainty of the prediction is roughly 19.87%. There seems to be a correlation between the training split and the prediction probability.

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# {'symbol': '$AAPL',
#  'score': tensor([[ 0.1987,  0.0382,  0.0966,  0.0942,  0.5722]]),
#  'timestamp': '2018-11-01T00:00:18Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
